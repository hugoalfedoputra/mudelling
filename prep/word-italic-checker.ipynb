# %%
import docx

# %%
# file_loc = 'E:/SKRIPSI/code/Test.docx'
file_loc = 'E:/SKRIPSI/Proposal Skripsi_Hugo Alfedo Putra_225150201111013.docx'

doc = docx.Document(file_loc)

all_paras = doc.paragraphs
len(all_paras)
# Out:
# 297

# %%
val_dic_loc = 'E:/05-Code-Projects/zewhat/server/dict/full_validation_dictionary.txt' 
indo_dic_loc = 'E:/SKRIPSI/code/prep/kbbi_words.txt'
indo_dic = []
val_dic = []

file = open(val_dic_loc, 'r')
raw_val_dic = file.readlines()

for raw_item in raw_val_dic:
    val_dic.append(raw_item.strip())

print('engval dict size', len(val_dic))
file.close()

file = open(indo_dic_loc, 'r', encoding='utf-8')
raw_indo_dic = file.readlines()

for raw_item in raw_indo_dic:
    indo_dic.append(raw_item.strip())

print('indo dict size', len(indo_dic))
file.close()
# Out:
# engval dict size 938662
# indo dict size 112651

# %%
okay_list = [
    'CNN',
    'GRU',
    'LSTM',
    'Self',
    'Attention',
    'Fourier',
    'Transform',
    'DFT',
    'FFT',
    'STFT',
    'Fully',
    'Connected',
    'Convolution',
    'Convolutional',
    'Network',
    'Neural',
    'FC',
    'MER',
    'MIR',
    'Music',
    'Emotion',
    'Recognition',
    'Information',
    'Retrieval',
    'Transformer',
    'Gated',
    'Recurrent',
    'Computer',
    'Vision',
    'CV',
    'log',
    'mel',
    'Discrete',
    'Hugo',
    'Machine',
    'Translation',
    'MediaEval',
    'ROC',
    'True',
    'False',
    'Positive',
    'Negative',
    'Rate',
    'Rate',
]

# %%
import string

translator = str.maketrans('', '', string.punctuation)

bib_texts = []
start_reading = 0
for para in all_paras:
    if para.text == "DAFTAR REFERENSI":
        start_reading = 1
        continue
    
    if start_reading == 0:
        continue
    else:
        runs = para.runs
        for run in runs:
            text = run.text.translate(translator)
            tokens = text.split(' ')

            if len(tokens) <= 1:
                continue
            # print(tokens)

            for token in tokens:
                # print(token)
                if len(token) > 1 and token[0].isupper():
                    bib_texts.append(token)
                if token.startswith('20'):
                    # print('ANOMALY FOUND')
                    break

print(len(bib_texts))
# print(all_authors)
# Out:
# 482

# %%
from pprint import pprint

translator = str.maketrans('', '', string.punctuation)

found_count = 0
found_list = set()

for para in all_paras:
    if para.text == "DAFTAR REFERENSI":
        break

    runs = para.runs
    for run in runs:
        text = run.text.translate(translator)

        isTextItalic = False if run.italic is None else True
        # It is now assumed that all the tokens in the text were not italicised
        tokens = text.split(' ')
        for token in tokens:
            if token.upper() in val_dic and token not in okay_list and token not in bib_texts and token.lower() not in indo_dic and not isTextItalic:
                # means that there is an English word that was not italicised (naive check)
                token_copy = tokens.copy()
                result = []
                for ctoken in token_copy:
                    if ctoken == token:
                        result.append(f'<<<{token.upper()}>>>')
                    else:
                        result.append(ctoken)
                print(f'Missing italics at word <<<{token}>>> in:\n{' '.join(result)}\n')
                found_count += 1
                found_list.add(token.lower())

if found_count > 0:
    print('There are missing italics!\n')
else:
    print('All done!')

pprint(found_list)
# Out:
# Missing italics at word <<<Cepstral>>> in:
#  Alternatif representasi seperti MelFrequency <<<CEPSTRAL>>> Coefficient MFCC ConstantQ Spectrogram Spectral Contrast
#
# Missing italics at word <<<Coefficient>>> in:
#  Alternatif representasi seperti MelFrequency Cepstral <<<COEFFICIENT>>> MFCC ConstantQ Spectrogram Spectral Contrast
#
# Missing italics at word <<<MFCC>>> in:
#  Alternatif representasi seperti MelFrequency Cepstral Coefficient <<<MFCC>>> ConstantQ Spectrogram Spectral Contrast
#
# Missing italics at word <<<Spectrogram>>> in:
#  Alternatif representasi seperti MelFrequency Cepstral Coefficient MFCC ConstantQ <<<SPECTROGRAM>>> Spectral Contrast
#
# Missing italics at word <<<Spectral>>> in:
#  Alternatif representasi seperti MelFrequency Cepstral Coefficient MFCC ConstantQ Spectrogram <<<SPECTRAL>>> Contrast
#
# Missing italics at word <<<Contrast>>> in:
#  Alternatif representasi seperti MelFrequency Cepstral Coefficient MFCC ConstantQ Spectrogram Spectral <<<CONTRAST>>>
#
# Missing italics at word <<<Chroma>>> in:
#  representasi harmonik seperti <<<CHROMA>>> dan Tonnetz tidak memberikan hasil yang lebih baik jika digunakan secara terpisah dibandingkan dengan
#
# Missing italics at word <<<RGB>>> in:
#  bukan tiga seperti pada gambar <<<RGB>>> Oleh karena itu penggunaan
#
# Missing italics at word <<<RGB>>> in:
#  secara arbitrer agar spektogram menjadi suatu gambar <<<RGB>>> Spektogram merepresentasikan pita frekuensi dan waktu Berbeda dengan gambar model yang mempelajari spektogram harus tidak terpengaruh oleh translasi dan penyesuaian skala
#
# Missing italics at word <<<Fast>>> in:
#  menggunakan Discrete Fourier Transform DFT pada sebuah sinyal digital Algoritma modern untuk menghitung DFT disebut <<<FAST>>> Fourier Transform FFT yaitu algoritma
#
# Missing italics at word <<<Cooley>>> in:
# adix2 CooleyTukey yang dirumuskan oleh <<<COOLEY>>> dan Tukey pada tahun 1965 Algoritma ini menghitung DFT dengan kompleksitas waktu logaritmik
#
# Missing italics at word <<<Tukey>>> in:
# adix2 CooleyTukey yang dirumuskan oleh Cooley dan <<<TUKEY>>> pada tahun 1965 Algoritma ini menghitung DFT dengan kompleksitas waktu logaritmik
#
# Missing italics at word <<<nya>>> in:
# <<<NYA>>>
#
# Missing italics at word <<<pitapita>>> in:
# <<<PITAPITA>>>
#
# Missing italics at word <<<Hz>>> in:
# Fungsi tersebut menerima masukan berupa frekuensi dalam satuan <<<HZ>>> dari spektogram untuk diskalakan secara LogMel Keluarannya juga dalam satuan <<<HZ>>> Penyesuaian skala ini umum digunakan dalam analisis audio
#
# Missing italics at word <<<Hz>>> in:
# Fungsi tersebut menerima masukan berupa frekuensi dalam satuan <<<HZ>>> dari spektogram untuk diskalakan secara LogMel Keluarannya juga dalam satuan <<<HZ>>> Penyesuaian skala ini umum digunakan dalam analisis audio
#
# Missing italics at word <<<hj>>> in:
# dan <<<HJ>>> sebagai
#
# Missing italics at word <<<Hadamard>>> in:
#  adalah produk <<<HADAMARD>>>
#
# Missing italics at word <<<BN>>> in:
# Batch Normalization <<<BN>>>
#
# Missing italics at word <<<BN>>> in:
# model menjadi divergen <<<BN>>>
#
# Missing italics at word <<<roses>>> in:
# <<<ROSES>>> penyesuaian skala dan pergeseran
#
# Missing italics at word <<<BN>>> in:
#  sebagai keluaran proses <<<BN>>> didefinisikan
#
# Missing italics at word <<<BN>>> in:
#  <<<BN>>> memungkinkan penggunaan
#
# Missing italics at word <<<LN>>> in:
# Layer Normalization <<<LN>>>
#
# Missing italics at word <<<BN>>> in:
# Ketergantungan <<<BN>>> pada
#
# Missing italics at word <<<nya>>> in:
# <<<NYA>>>
#
# Missing italics at word <<<LN>>> in:
#  <<<LN>>> sebagai teknik untuk mentransposisi dimensi normalisasi dari
#
# Missing italics at word <<<LN>>> in:
# Penghitungan <<<LN>>> ditentukan sematamata
#
# Missing italics at word <<<BN>>> in:
# dibandingkan pada <<<BN>>> yang akan menggunakan penghitungan statistik yang berbeda pada
#
# Missing italics at word <<<LN>>> in:
# <<<LN>>> secara matematis
#
# Missing italics at word <<<LN>>> in:
# Keluaran dari <<<LN>>>
#
# Missing italics at word <<<BN>>> in:
# penyesuaian skala dan pergeseran serupa dengan pada <<<BN>>>
#
# Missing italics at word <<<BN>>> in:
#  pada <<<BN>>>
#
# Missing italics at word <<<an>>> in:
# <<<AN>>>
#
# Missing italics at word <<<Average>>> in:
#  mengusulkan strategi peratarataan yang disebut Global <<<AVERAGE>>> Pooling GAP untuk
#
# Missing italics at word <<<Pooling>>> in:
#  mengusulkan strategi peratarataan yang disebut Global Average <<<POOLING>>> GAP untuk
#
# Missing italics at word <<<Adaptive>>> in:
# <<<ADAPTIVE>>> Moment Estimation ADAM
#
# Missing italics at word <<<Moment>>> in:
# Adaptive <<<MOMENT>>> Estimation ADAM
#
# Missing italics at word <<<Estimation>>> in:
# Adaptive Moment <<<ESTIMATION>>> ADAM
#
# Missing italics at word <<<Adaptive>>> in:
#  Algoritma ini mengintegrasikan keunggulan dari <<<ADAPTIVE>>> Gradient Algorithm AdaGrad yang mempertahankan
#
# Missing italics at word <<<Gradient>>> in:
#  Algoritma ini mengintegrasikan keunggulan dari Adaptive <<<GRADIENT>>> Algorithm AdaGrad yang mempertahankan
#
# Missing italics at word <<<Algorithm>>> in:
#  Algoritma ini mengintegrasikan keunggulan dari Adaptive Gradient <<<ALGORITHM>>> AdaGrad yang mempertahankan
#
# Missing italics at word <<<Binary>>> in:
# Fungsi Rugi <<<BINARY>>> CrossEntropy BCE
#
# Missing italics at word <<<CrossEntropy>>> in:
# Fungsi Rugi Binary <<<CROSSENTROPY>>> BCE
#
# Missing italics at word <<<BCE>>> in:
# Fungsi Rugi Binary CrossEntropy <<<BCE>>>
#
# Missing italics at word <<<BCE>>> in:
# <<<BCE>>> adalah fungsi rugi
#
# Missing italics at word <<<BCE>>> in:
#  <<<BCE>>> dirancang untuk
#
# Missing italics at word <<<Bishop>>> in:
# menghasilkan jumlah evaluasi yang sama dengan jumlah label Dalam <<<BISHOP>>> 2006
#
# Missing italics at word <<<Under>>> in:
# Area <<<UNDER>>> the Receiver Operating Characteristics Curve ROCAUC dan Area <<<UNDER>>> the PrecisionRecall Curve PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<the>>> in:
# Area Under <<<THE>>> Receiver Operating Characteristics Curve ROCAUC dan Area Under <<<THE>>> PrecisionRecall Curve PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<Receiver>>> in:
# Area Under the <<<RECEIVER>>> Operating Characteristics Curve ROCAUC dan Area Under the PrecisionRecall Curve PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<Operating>>> in:
# Area Under the Receiver <<<OPERATING>>> Characteristics Curve ROCAUC dan Area Under the PrecisionRecall Curve PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<Characteristics>>> in:
# Area Under the Receiver Operating <<<CHARACTERISTICS>>> Curve ROCAUC dan Area Under the PrecisionRecall Curve PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<Curve>>> in:
# Area Under the Receiver Operating Characteristics <<<CURVE>>> ROCAUC dan Area Under the PrecisionRecall <<<CURVE>>> PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<Under>>> in:
# Area <<<UNDER>>> the Receiver Operating Characteristics Curve ROCAUC dan Area <<<UNDER>>> the PrecisionRecall Curve PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<the>>> in:
# Area Under <<<THE>>> Receiver Operating Characteristics Curve ROCAUC dan Area Under <<<THE>>> PrecisionRecall Curve PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<Curve>>> in:
# Area Under the Receiver Operating Characteristics <<<CURVE>>> ROCAUC dan Area Under the PrecisionRecall <<<CURVE>>> PRAUC adalah metrik evaluasi
#
# Missing italics at word <<<peng>>> in:
# model <<<PENG>>>
#
# Missing italics at word <<<nya>>> in:
# <<<NYA>>> untuk mendapatkan nilai PR dan ROC
#
# Missing italics at word <<<Hz>>> in:
#  44100 <<<HZ>>> Berkasberkas ini telah di
#
# Missing italics at word <<<Hz>>> in:
#  16000 <<<HZ>>>
#
# Missing italics at word <<<Hz>>> in:
#  yaitu 44100 <<<HZ>>>
#
# Missing italics at word <<<nya>>> in:
# <<<NYA>>> masingmasing dilatih secara terpisah Walaupun arsitektur
#
# There are missing italics!
#
# {'adaptive',
#  'algorithm',
#  'an',
#  'average',
#  'bce',
#  'binary',
#  'bishop',
#  'bn',
#  'cepstral',
#  'characteristics',
#  'chroma',
#  'coefficient',
#  'contrast',
#  'cooley',
#  'crossentropy',
#  'curve',
#  'estimation',
#  'fast',
#  'gradient',
#  'hadamard',
#  'hj',
#  'hz',
#  'ln',
#  'mfcc',
#  'moment',
#  'nya',
#  'operating',
#  'peng',
#  'pitapita',
#  'pooling',
#  'receiver',
#  'rgb',
#  'roses',
#  'spectral',
#  'spectrogram',
#  'the',
#  'tukey',
#  'under'}
